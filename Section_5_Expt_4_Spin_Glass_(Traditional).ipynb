# %%
import torch
import numpy as np
import math
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Spin glass Hamiltonian ---
def spin_glass_energy(params, J):
    spins = torch.tanh(params)
    E = -torch.sum(J * torch.outer(spins, spins))
    return E / 2.0

# ----------------------------------------------------------------------
# NDDA computation (pure indicator, no update)
# ----------------------------------------------------------------------
def compute_NDDA(params, J, alpha=1.3):
    params = params.clone().detach().to(device).requires_grad_(True)
    d = params.numel()

    epsilon = torch.randn_like(params)
    params_1 = params + epsilon
    E1 = spin_glass_energy(params_1, J)
    E1.backward()
    I1 = epsilon * params.grad
    params.grad.zero_()

    mask_descent = (I1 < 0).to(device)
    mask_ascent  = (I1 > 0).to(device)
    epsilon_prime = torch.where(mask_descent, alpha * epsilon, epsilon)
    epsilon_prime = torch.where(mask_ascent, -epsilon, epsilon_prime)

    params_2 = params + epsilon_prime
    E2 = spin_glass_energy(params_2, J)
    E2.backward()
    I2 = epsilon_prime * params.grad
    params.grad.zero_()

    ndda_count = torch.sum((I1 >= 0) & (I2 >= 0)).float()
    return (ndda_count / d).item()

# ----------------------------------------------------------------------
# CPA optimizer with Hessian analysis
# ----------------------------------------------------------------------
def optimize_CPA(params_init, J, sigma_begin=0.02, sigma_end=0.001, epochs=200, alpha=1.3):
    J = J.clone().detach().to(device).requires_grad_(False)
    params = params_init.clone().detach().to(device).requires_grad_(True)

    losses = []
    ndda_vals = []
    min_eigenvalues = []       # most negative eigenvalue each 100 epochs
    len_of_params = params.numel()

    for epoch in range(epochs):
        sigma = sigma_begin * (1. - epoch/epochs) + sigma_end * epoch/epochs


        # --- CPA two-probe ---
        epsilon = (torch.randn_like(params)).detach().to(device).requires_grad_(False)
        params_1 = params + epsilon
        E1 = spin_glass_energy(params_1, J)
        E1.backward()
        I1 = epsilon * params.grad
        params.grad.zero_()

        mask_descent = (I1 < 0).to(device)
        mask_ascent  = (I1 > 0).to(device)
        epsilon_prime = torch.where(mask_descent, alpha * epsilon, epsilon)
        epsilon_prime = (torch.where(mask_ascent, -epsilon, epsilon_prime)).detach().to(device).requires_grad_(False)

        params_2 = params + epsilon_prime
        E2 = spin_glass_energy(params_2, J)
        E2.backward()
        I2 = epsilon_prime * params.grad
        params.grad.zero_()

        # Full CPA update: I2 < 0 or (I1 < 0 and I2 >= 0)
        update_mask = (I2 < 0) | ((I1 < 0) & (I2 >= 0)).to(device)
        perturbation = torch.where((I2 < 0), epsilon_prime, epsilon)
        perturbation = perturbation * update_mask.float()

        with torch.no_grad():
            params += perturbation
            E_final = spin_glass_energy(params, J)
            losses.append(E_final.item() / N)

        ndda_vals.append(compute_NDDA(params, J, alpha))

        # ---- Hessian analysis every 100 epochs ----
        if epoch % 100 == 0:
            mu_Hessian = params.clone().detach().to(device).requires_grad_(True)
            y = spin_glass_energy(mu_Hessian, J)
            grad = torch.autograd.grad(y, mu_Hessian, create_graph=True)[0]

            dim = mu_Hessian.shape[0]
            H = torch.zeros(dim, dim)
            for i in range(dim):
                grad2 = torch.autograd.grad(grad[i], mu_Hessian, create_graph=True)[0]
                H[i] = grad2
            eigenvalues, _ = torch.linalg.eig(H)
            eigenvalues = eigenvalues.real
            min_eigenvalues.append(torch.min(eigenvalues).item())

            # Store additional diagnostics (optional)
            # num_nonnegative = (eigenvalues >= 0).sum().item()
            # total = eigenvalues.numel()
            # etc.
        else:
            # keep last value for continuous time-series
            if len(min_eigenvalues) > 0:
                min_eigenvalues.append(min_eigenvalues[-1])
            else:
                min_eigenvalues.append(None)

        if epoch % 100 == 0:
            print(f"epoch: {epoch:5d}  CPA  loss/N: {losses[-1]:.6f}  NDDA: {ndda_vals[-1]:.4f} min_eigenvalue: {min_eigenvalues[-1]:.6f}")

    return losses, ndda_vals, min_eigenvalues

def switch_to_CPA(params_init, J, sigma, alpha=1.3):
    J = J.clone().detach().to(device).requires_grad_(False)
    params = params_init.clone().detach().to(device).requires_grad_(True)

    losses = []
    ndda_vals = []
    min_eigenvalues = []       # most negative eigenvalue each 100 epochs
    len_of_params = params.numel()


        # --- CPA two-probe ---
    epsilon = (torch.randn_like(params) * sigma).detach().to(device).requires_grad_(False)
    params_1 = params + epsilon
    E1 = spin_glass_energy(params_1, J)
    E1.backward()
    I1 = epsilon * params.grad
    params.grad.zero_()

    mask_descent = (I1 < 0).to(device)
    mask_ascent  = (I1 > 0).to(device)
    epsilon_prime = torch.where(mask_descent, alpha * epsilon, epsilon)
    epsilon_prime = (torch.where(mask_ascent, -epsilon, epsilon_prime)).detach().to(device).requires_grad_(False)

    params_2 = params + epsilon_prime
    E2 = spin_glass_energy(params_2, J)
    E2.backward()
    I2 = epsilon_prime * params.grad
    params.grad.zero_()

        # Full CPA update: I2 < 0 or (I1 < 0 and I2 >= 0)
    update_mask = (I2 < 0) | ((I1 < 0) & (I2 >= 0)).to(device)
    perturbation = torch.where((I2 < 0), epsilon_prime, epsilon)
    perturbation = perturbation * update_mask.float()
    with torch.no_grad():
        params += perturbation

    return params 

# ----------------------------------------------------------------------
# GD / PGD optimizer with Hessian analysis
# ----------------------------------------------------------------------
def optimize_GD_then_PGD_or_CPA(params_init, J, sigma_begin=0.02, sigma_end=0.001, escape_method = "CPA", epochs=10):
    method="GD"
    J = J.clone().detach().to(device).requires_grad_(False)
    params = params_init.clone().detach().to(device).requires_grad_(True)
    losses = []
    ndda_vals = []
    min_eigenvalues = []

    for epoch in range(epochs):
        lrlr = sigma_begin * (1. - epoch/epochs) + sigma_end * epoch/epochs
        energy = spin_glass_energy(params, J)
        losses.append(energy.item() / N)
        
        if method == "GD":
            energy.backward()
            with torch.no_grad():
                   params -= lrlr * params.grad
        elif method == "PGD":
            energy.backward()
            with torch.no_grad():    
                noise = torch.randn_like(params)
                params -= lrlr * (params.grad + noise)
        elif method == "CPA":
            params = switch_to_CPA(params, J, sigma=lrlr)

        params.grad.zero_()
        ndda_vals.append(compute_NDDA(params, J))

        mu_Hessian = params.clone().detach().to(device).requires_grad_(True)
        y = spin_glass_energy(mu_Hessian, J)
        grad = torch.autograd.grad(y, mu_Hessian, create_graph=True)[0]
        max_grad_norm = torch.max(torch.abs(grad)).item()
        if max_grad_norm < 1.5e-2:
            temp = method
            method = escape_method
            if temp != escape_method:
                print(f"Switching to {escape_method} at epoch {epoch} due to small gradient norm: {max_grad_norm:.5e}")
        else:
            temp = method
            method="GD"
            if temp != "GD":
                print(f"Switching back to GD at epoch {epoch} due to large gradient norm: {max_grad_norm:.5e}")           

        # Hessian analysis every 100 epochs
        if epoch % 100 == 0:
            mu_Hessian = params.clone().detach().to(device).requires_grad_(True)
            y = spin_glass_energy(mu_Hessian, J)
            grad = torch.autograd.grad(y, mu_Hessian, create_graph=True)[0]

            dim = mu_Hessian.shape[0]
            H = torch.zeros(dim, dim)
            for i in range(dim):
                grad2 = torch.autograd.grad(grad[i], mu_Hessian, create_graph=True)[0]
                H[i] = grad2
            eigenvalues, _ = torch.linalg.eig(H)
            eigenvalues = eigenvalues.real
            min_eigenvalues.append(torch.min(eigenvalues).item())
        else:
            if len(min_eigenvalues) > 0:
                min_eigenvalues.append(min_eigenvalues[-1])
            else:
                min_eigenvalues.append(None)

        if epoch % 100 == 0:
            print(f"epoch: {epoch:5d}  {method}  loss/N: {losses[-1]:.6f}  NDDA: {ndda_vals[-1]:.4f}  "
                  f"min_eigenvalue: {min_eigenvalues[-1]:.6f} max_grad_norm:{max_grad_norm:.5e}")

    return losses, ndda_vals, min_eigenvalues

# ----------------------------------------------------------------------
# Run experiment
# ----------------------------------------------------------------------
N = 1000
epoch_no = 30000
torch.manual_seed(0)

# J matrix construction
J = torch.randn((N, N), device=device, dtype=torch.float32)
J = (J + J.T) / 2.0
J = J * math.sqrt(1.0 / N)
J.diagonal().zero_()

params0 = 0.4 * torch.randn(N, device=device)
logvar0 = -0.1 * torch.ones(N, device=device)   # not used in the new functions, but kept for compatibility

# Run optimizers
CPA_losses, CPA_ndda, CPA_min_eig = optimize_GD_then_PGD_or_CPA(params0, J, sigma_begin=0.4, sigma_end=0.001, escape_method="CPA", epochs=epoch_no)
PGD_losses, PGD_ndda, PGD_min_eig = optimize_GD_then_PGD_or_CPA(params0, J, sigma_begin=0.4, sigma_end=0.001, escape_method="PGD", epochs=epoch_no)

print("GD + CPA final loss:", CPA_losses[-1])
print("GD + PGD final loss:", PGD_losses[-1])


# ----------------------------------------------------------------------
# Plots
# ----------------------------------------------------------------------
# Energy
plt.figure(figsize=(9,5))
plt.plot(PGD_losses, label="GD + PGD")
plt.plot(CPA_losses, label="GD + CPA")
plt.xlabel("Epoch")
plt.ylabel("Energy")
plt.legend()
plt.title(f"Spin Glass Variational Optimization (N={N})")
plt.savefig("energy.png")
plt.close()

# NDDA index
plt.figure(figsize=(9,5))
plt.plot(PGD_ndda, label="GD + PGD")
plt.plot(CPA_ndda, label="GD + CPA")
plt.xlabel("Epoch")
plt.ylabel("NDDA")
plt.legend()
plt.title(f"NDDA Index (N={N})")
plt.savefig("ndda.png")
plt.close()

# Most negative eigenvalue (min eigenvalue)
plt.figure(figsize=(9,5))
# Only plot if values exist (skip Nones)
cpa_min_eig_arr = np.array([v if v is not None else np.nan for v in CPA_min_eig])
pgd_min_eig_arr = np.array([v if v is not None else np.nan for v in PGD_min_eig])
plt.plot(pgd_min_eig_arr, label="GD + PGD")
plt.plot(cpa_min_eig_arr, label="GD + CPA")
plt.xlabel("Epoch")
plt.ylabel("Minimum Eigenvalue")
plt.legend()
plt.title(f"Most Negative Eigenvalue (N={N})")
plt.savefig("min_eigenvalue.png")
plt.close()
# Out:
# epoch:     0  GD  loss/N: -0.000625  NDDA: 0.3180  min_eigenvalue: -1.130604 max_grad_norm:7.24616e-01
# epoch:   100  GD  loss/N: -0.433626  NDDA: 0.0160  min_eigenvalue: -0.265006 max_grad_norm:2.31984e-01
# epoch:   200  GD  loss/N: -0.445326  NDDA: 0.0160  min_eigenvalue: -0.217907 max_grad_norm:2.14515e-01
# epoch:   300  GD  loss/N: -0.450072  NDDA: 0.0090  min_eigenvalue: -0.111950 max_grad_norm:2.24749e-01
# epoch:   400  GD  loss/N: -0.452903  NDDA: 0.0050  min_eigenvalue: -0.178196 max_grad_norm:1.53341e-01
# epoch:   500  GD  loss/N: -0.457972  NDDA: 0.0030  min_eigenvalue: -0.040066 max_grad_norm:6.22369e-02
# epoch:   600  GD  loss/N: -0.458639  NDDA: 0.0020  min_eigenvalue: -0.068042 max_grad_norm:4.77419e-02
# epoch:   700  GD  loss/N: -0.459355  NDDA: 0.0020  min_eigenvalue: -0.053046 max_grad_norm:1.90422e-01
# epoch:   800  GD  loss/N: -0.460547  NDDA: 0.0030  min_eigenvalue: -0.096972 max_grad_norm:7.22347e-02
# epoch:   900  GD  loss/N: -0.461567  NDDA: 0.0000  min_eigenvalue: -0.041826 max_grad_norm:2.96189e-02
# epoch:  1000  GD  loss/N: -0.462578  NDDA: 0.0020  min_eigenvalue: -0.112592 max_grad_norm:1.31257e-01
# epoch:  1100  GD  loss/N: -0.462930  NDDA: 0.0030  min_eigenvalue: -0.092369 max_grad_norm:5.72902e-02
# epoch:  1200  GD  loss/N: -0.463328  NDDA: 0.0010  min_eigenvalue: -0.101629 max_grad_norm:8.17917e-02
# epoch:  1300  GD  loss/N: -0.463597  NDDA: 0.0010  min_eigenvalue: -0.004254 max_grad_norm:1.80062e-02
# Switching to CPA at epoch 1316 due to small gradient norm: 1.49181e-02
# Switching back to GD at epoch 1318 due to large gradient norm: 1.53341e-02
# epoch:  1400  GD  loss/N: -0.464080  NDDA: 0.0060  min_eigenvalue: -0.105409 max_grad_norm:1.12266e-01
# epoch:  1500  GD  loss/N: -0.464349  NDDA: 0.0020  min_eigenvalue: -0.020337 max_grad_norm:1.68216e-02
# Switching to CPA at epoch 1511 due to small gradient norm: 1.48569e-02
# Switching back to GD at epoch 1512 due to large gradient norm: 2.99157e-02
# epoch:  1600  GD  loss/N: -0.465223  NDDA: 0.0040  min_eigenvalue: -0.040633 max_grad_norm:4.58431e-02
# epoch:  1700  GD  loss/N: -0.465633  NDDA: 0.0030  min_eigenvalue: -0.115944 max_grad_norm:7.79834e-02
# epoch:  1800  GD  loss/N: -0.465991  NDDA: 0.0010  min_eigenvalue: -0.029043 max_grad_norm:1.86582e-02
# epoch:  1900  GD  loss/N: -0.466195  NDDA: 0.0020  min_eigenvalue: -0.028006 max_grad_norm:1.48721e-01
# epoch:  2000  GD  loss/N: -0.466423  NDDA: 0.0010  min_eigenvalue: -0.006472 max_grad_norm:1.71948e-02
# Switching to CPA at epoch 2013 due to small gradient norm: 1.49623e-02
# Switching back to GD at epoch 2015 due to large gradient norm: 1.99480e-02
# epoch:  2100  GD  loss/N: -0.466599  NDDA: 0.0110  min_eigenvalue: -0.009179 max_grad_norm:8.24467e-02
# epoch:  2200  GD  loss/N: -0.466672  NDDA: 0.0060  min_eigenvalue: -0.015405 max_grad_norm:1.51120e-02
# Switching to CPA at epoch 2201 due to small gradient norm: 1.49601e-02
# Switching back to GD at epoch 2203 due to large gradient norm: 3.90174e-02
# epoch:  2300  GD  loss/N: -0.466866  NDDA: 0.0740  min_eigenvalue: -0.023654 max_grad_norm:2.74925e-02
# epoch:  2400  GD  loss/N: -0.466899  NDDA: 0.0450  min_eigenvalue: -0.015515 max_grad_norm:1.50022e-02
# Switching to CPA at epoch 2401 due to small gradient norm: 1.48929e-02
# Switching back to GD at epoch 2404 due to large gradient norm: 3.27149e-02
# epoch:  2500  GD  loss/N: -0.467339  NDDA: 0.2240  min_eigenvalue: -0.051820 max_grad_norm:1.19398e-01
# epoch:  2600  GD  loss/N: -0.467706  NDDA: 0.2480  min_eigenvalue: -0.057520 max_grad_norm:4.32004e-02
# epoch:  2700  GD  loss/N: -0.467857  NDDA: 0.2360  min_eigenvalue: -0.010292 max_grad_norm:2.55329e-02
# Switching to CPA at epoch 2745 due to small gradient norm: 1.48828e-02
# Switching back to GD at epoch 2747 due to large gradient norm: 1.52965e-02
# epoch:  2800  GD  loss/N: -0.467918  NDDA: 0.4510  min_eigenvalue: -0.059876 max_grad_norm:3.36541e-02
# epoch:  2900  GD  loss/N: -0.468488  NDDA: 0.4360  min_eigenvalue: -0.013133 max_grad_norm:1.49609e-01
# epoch:  3000  GD  loss/N: -0.468618  NDDA: 0.4350  min_eigenvalue: -0.024037 max_grad_norm:1.62693e-02
# epoch:  3100  GD  loss/N: -0.468667  NDDA: 0.4320  min_eigenvalue: -0.072922 max_grad_norm:5.86273e-02
# epoch:  3200  GD  loss/N: -0.468822  NDDA: 0.4370  min_eigenvalue: -0.001011 max_grad_norm:2.21635e-02
# Switching to CPA at epoch 3234 due to small gradient norm: 1.48954e-02
# Switching back to GD at epoch 3237 due to large gradient norm: 1.68459e-02
# epoch:  3300  GD  loss/N: -0.468879  NDDA: 0.7100  min_eigenvalue: -0.051381 max_grad_norm:4.01135e-02
# epoch:  3400  GD  loss/N: -0.468975  NDDA: 0.6910  min_eigenvalue: -0.003094 max_grad_norm:2.70544e-02
# Switching to CPA at epoch 3451 due to small gradient norm: 1.49454e-02
# Switching back to GD at epoch 3456 due to large gradient norm: 1.75012e-02
# epoch:  3500  GD  loss/N: -0.469020  NDDA: 0.9090  min_eigenvalue: -0.054264 max_grad_norm:3.31553e-02
# epoch:  3600  GD  loss/N: -0.469188  NDDA: 0.8880  min_eigenvalue: -0.032554 max_grad_norm:3.48132e-02
# epoch:  3700  GD  loss/N: -0.469725  NDDA: 0.8880  min_eigenvalue: -0.016566 max_grad_norm:2.35303e-01
# epoch:  3800  GD  loss/N: -0.469898  NDDA: 0.9070  min_eigenvalue: -0.037623 max_grad_norm:2.01496e-02
# epoch:  3900  GD  loss/N: -0.470149  NDDA: 0.8950  min_eigenvalue: -0.000228 max_grad_norm:9.02465e-02
# Switching to CPA at epoch 3990 due to small gradient norm: 1.49552e-02
# Switching back to GD at epoch 3996 due to large gradient norm: 2.89235e-02
# epoch:  4000  GD  loss/N: -0.470237  NDDA: 0.9510  min_eigenvalue: -0.050940 max_grad_norm:3.09659e-02
# epoch:  4100  GD  loss/N: -0.470401  NDDA: 0.9460  min_eigenvalue: -0.044610 max_grad_norm:3.89545e-02
# epoch:  4200  GD  loss/N: -0.470514  NDDA: 0.9450  min_eigenvalue: -0.001910 max_grad_norm:3.80909e-02
# Switching to CPA at epoch 4273 due to small gradient norm: 1.49190e-02
# Switching back to GD at epoch 4278 due to large gradient norm: 2.11188e-02
# epoch:  4300  GD  loss/N: -0.470556  NDDA: 0.9670  min_eigenvalue: -0.046248 max_grad_norm:2.87331e-02
# epoch:  4400  GD  loss/N: -0.470679  NDDA: 0.9640  min_eigenvalue: -0.002616 max_grad_norm:4.25885e-02
# Switching to CPA at epoch 4476 due to small gradient norm: 1.49341e-02
# Switching back to GD at epoch 4480 due to large gradient norm: 1.74738e-02
# epoch:  4500  GD  loss/N: -0.470720  NDDA: 0.9790  min_eigenvalue: -0.027722 max_grad_norm:2.09252e-02
# epoch:  4600  GD  loss/N: -0.470754  NDDA: 0.9620  min_eigenvalue: -0.003278 max_grad_norm:3.47080e-02
# Switching to CPA at epoch 4695 due to small gradient norm: 1.49744e-02
# Switching back to GD at epoch 4700 due to large gradient norm: 1.70616e-02
# epoch:  4700  GD  loss/N: -0.470788  NDDA: 0.9730  min_eigenvalue: -0.028336 max_grad_norm:1.70616e-02
# epoch:  4800  GD  loss/N: -0.470834  NDDA: 0.9770  min_eigenvalue: -0.015676 max_grad_norm:5.45202e-02
# epoch:  4900  GD  loss/N: -0.470891  NDDA: 0.9750  min_eigenvalue: -0.037685 max_grad_norm:2.01180e-02
# epoch:  5000  GD  loss/N: -0.471146  NDDA: 0.9720  min_eigenvalue: -0.000887 max_grad_norm:1.07087e-01
# Switching to CPA at epoch 5098 due to small gradient norm: 1.48878e-02
# epoch:  5100  CPA  loss/N: -0.471219  NDDA: 0.9740  min_eigenvalue: -0.012436 max_grad_norm:8.64630e-03
# Switching back to GD at epoch 5105 due to large gradient norm: 1.70878e-02
# epoch:  5200  GD  loss/N: -0.471251  NDDA: 0.9790  min_eigenvalue: -0.000045 max_grad_norm:2.43334e-02
# Switching to CPA at epoch 5300 due to small gradient norm: 1.49263e-02
# epoch:  5300  CPA  loss/N: -0.471264  NDDA: 0.9770  min_eigenvalue: -0.000050 max_grad_norm:1.49263e-02
# Switching back to GD at epoch 5310 due to large gradient norm: 1.70299e-02
# epoch:  5400  GD  loss/N: -0.471331  NDDA: 0.9750  min_eigenvalue: -0.073966 max_grad_norm:8.29981e-02
# epoch:  5500  GD  loss/N: -0.471471  NDDA: 0.9770  min_eigenvalue: -0.004670 max_grad_norm:2.11731e-02
# Switching to CPA at epoch 5533 due to small gradient norm: 1.49356e-02
# Switching back to GD at epoch 5537 due to large gradient norm: 2.85434e-02
# epoch:  5600  GD  loss/N: -0.471553  NDDA: 0.9760  min_eigenvalue: -0.012303 max_grad_norm:7.21250e-02
# epoch:  5700  GD  loss/N: -0.471621  NDDA: 0.9770  min_eigenvalue: -0.011957 max_grad_norm:1.84987e-02
# Switching to CPA at epoch 5722 due to small gradient norm: 1.49867e-02
# Switching back to GD at epoch 5723 due to large gradient norm: 1.54527e-02
# epoch:  5800  GD  loss/N: -0.471668  NDDA: 0.9720  min_eigenvalue: -0.080359 max_grad_norm:4.54935e-02
# epoch:  5900  GD  loss/N: -0.472128  NDDA: 0.9760  min_eigenvalue: -0.001766 max_grad_norm:3.02996e-02
# Switching to CPA at epoch 5960 due to small gradient norm: 1.49851e-02
# Switching back to GD at epoch 5966 due to large gradient norm: 2.71507e-02
# epoch:  6000  GD  loss/N: -0.472198  NDDA: 0.9790  min_eigenvalue: -0.045702 max_grad_norm:4.37297e-02
# epoch:  6100  GD  loss/N: -0.472277  NDDA: 0.9730  min_eigenvalue: -0.020249 max_grad_norm:2.73398e-02
# epoch:  6200  GD  loss/N: -0.472297  NDDA: 0.9770  min_eigenvalue: -0.041868 max_grad_norm:2.56855e-02
# epoch:  6300  GD  loss/N: -0.472397  NDDA: 0.9780  min_eigenvalue: -0.000048 max_grad_norm:5.44490e-02
# epoch:  6400  GD  loss/N: -0.472436  NDDA: 0.9720  min_eigenvalue: -0.000033 max_grad_norm:1.50166e-02
# Switching to CPA at epoch 6401 due to small gradient norm: 1.48928e-02
# Switching back to GD at epoch 6417 due to large gradient norm: 3.21388e-02
# epoch:  6500  GD  loss/N: -0.472600  NDDA: 0.9720  min_eigenvalue: -0.045785 max_grad_norm:6.22977e-02
# epoch:  6600  GD  loss/N: -0.472743  NDDA: 0.9810  min_eigenvalue: -0.009749 max_grad_norm:4.94040e-02
# Switching to CPA at epoch 6693 due to small gradient norm: 1.48755e-02
# Switching back to GD at epoch 6694 due to large gradient norm: 2.02391e-02
# epoch:  6700  GD  loss/N: -0.472786  NDDA: 0.9770  min_eigenvalue: -0.038923 max_grad_norm:2.17169e-02
# epoch:  6800  GD  loss/N: -0.472926  NDDA: 0.9790  min_eigenvalue: -0.003783 max_grad_norm:9.58384e-02
# epoch:  6900  GD  loss/N: -0.472994  NDDA: 0.9780  min_eigenvalue: -0.004190 max_grad_norm:1.67406e-02
# Switching to CPA at epoch 6913 due to small gradient norm: 1.48904e-02
# Switching back to GD at epoch 6915 due to large gradient norm: 3.00105e-02
# epoch:  7000  GD  loss/N: -0.473597  NDDA: 0.9720  min_eigenvalue: -0.009493 max_grad_norm:8.29956e-02
# Switching to CPA at epoch 7094 due to small gradient norm: 1.48935e-02
# Switching back to GD at epoch 7095 due to large gradient norm: 2.26169e-02
# epoch:  7100  GD  loss/N: -0.473649  NDDA: 0.9760  min_eigenvalue: -0.046557 max_grad_norm:2.42168e-02
# epoch:  7200  GD  loss/N: -0.474232  NDDA: 0.9760  min_eigenvalue: -0.002746 max_grad_norm:8.09874e-02
# Switching to CPA at epoch 7294 due to small gradient norm: 1.49260e-02
# epoch:  7300  CPA  loss/N: -0.474292  NDDA: 0.9760  min_eigenvalue: -0.003492 max_grad_norm:1.38655e-02
# Switching back to GD at epoch 7305 due to large gradient norm: 2.43482e-02
# epoch:  7400  GD  loss/N: -0.474574  NDDA: 0.9770  min_eigenvalue: -0.091429 max_grad_norm:1.05466e-01
# epoch:  7500  GD  loss/N: -0.474832  NDDA: 0.9770  min_eigenvalue: -0.004613 max_grad_norm:2.29091e-02
# Switching to CPA at epoch 7542 due to small gradient norm: 1.49264e-02
# Switching back to GD at epoch 7547 due to large gradient norm: 1.52505e-02
# epoch:  7600  GD  loss/N: -0.474871  NDDA: 0.9770  min_eigenvalue: -0.030143 max_grad_norm:2.34291e-02
# epoch:  7700  GD  loss/N: -0.474907  NDDA: 0.9750  min_eigenvalue: -0.006179 max_grad_norm:3.74787e-02
# epoch:  7800  GD  loss/N: -0.474929  NDDA: 0.9770  min_eigenvalue: -0.006747 max_grad_norm:1.63153e-02
# Switching to CPA at epoch 7812 due to small gradient norm: 1.49549e-02
# Switching back to GD at epoch 7815 due to large gradient norm: 3.24644e-02
# epoch:  7900  GD  loss/N: -0.475046  NDDA: 0.9790  min_eigenvalue: -0.009467 max_grad_norm:6.01203e-02
# epoch:  8000  GD  loss/N: -0.475081  NDDA: 0.9770  min_eigenvalue: -0.013611 max_grad_norm:1.62806e-02
# Switching to CPA at epoch 8011 due to small gradient norm: 1.48838e-02
# Switching back to GD at epoch 8014 due to large gradient norm: 2.11382e-02
# epoch:  8100  GD  loss/N: -0.475235  NDDA: 0.9750  min_eigenvalue: -0.151999 max_grad_norm:1.99407e-01
# epoch:  8200  GD  loss/N: -0.475589  NDDA: 0.9750  min_eigenvalue: -0.042790 max_grad_norm:5.66891e-02
# epoch:  8300  GD  loss/N: -0.475671  NDDA: 0.9740  min_eigenvalue: -0.003339 max_grad_norm:2.59759e-02
# Switching to CPA at epoch 8358 due to small gradient norm: 1.49693e-02
# Switching back to GD at epoch 8362 due to large gradient norm: 3.01797e-02
# epoch:  8400  GD  loss/N: -0.475753  NDDA: 0.9760  min_eigenvalue: -0.062522 max_grad_norm:5.38875e-02
# epoch:  8500  GD  loss/N: -0.476042  NDDA: 0.9740  min_eigenvalue: -0.095665 max_grad_norm:6.04404e-02
# epoch:  8600  GD  loss/N: -0.476355  NDDA: 0.9740  min_eigenvalue: -0.046312 max_grad_norm:3.11745e-02
# epoch:  8700  GD  loss/N: -0.476491  NDDA: 0.9750  min_eigenvalue: -0.009018 max_grad_norm:6.86622e-02
# epoch:  8800  GD  loss/N: -0.476535  NDDA: 0.9710  min_eigenvalue: -0.013444 max_grad_norm:1.67702e-02
# Switching to CPA at epoch 8814 due to small gradient norm: 1.49631e-02
# Switching back to GD at epoch 8815 due to large gradient norm: 2.01520e-02
# epoch:  8900  GD  loss/N: -0.476581  NDDA: 0.9720  min_eigenvalue: -0.034378 max_grad_norm:5.36122e-02
# epoch:  9000  GD  loss/N: -0.476648  NDDA: 0.9780  min_eigenvalue: -0.000028 max_grad_norm:2.62466e-02
# Switching to CPA at epoch 9063 due to small gradient norm: 1.49186e-02
# Switching back to GD at epoch 9078 due to large gradient norm: 3.34995e-02
# epoch:  9100  GD  loss/N: -0.476709  NDDA: 0.9800  min_eigenvalue: -0.087617 max_grad_norm:5.20117e-02
# epoch:  9200  GD  loss/N: -0.477020  NDDA: 0.9750  min_eigenvalue: -0.010305 max_grad_norm:3.62393e-02
# Switching to CPA at epoch 9276 due to small gradient norm: 1.48855e-02
# Switching back to GD at epoch 9278 due to large gradient norm: 3.63106e-02
# epoch:  9300  GD  loss/N: -0.477083  NDDA: 0.9790  min_eigenvalue: -0.053658 max_grad_norm:4.92610e-02
# epoch:  9400  GD  loss/N: -0.477181  NDDA: 0.9810  min_eigenvalue: -0.015861 max_grad_norm:3.18009e-02
# Switching to CPA at epoch 9474 due to small gradient norm: 1.49405e-02
# Switching back to GD at epoch 9475 due to large gradient norm: 2.21257e-02
# epoch:  9500  GD  loss/N: -0.477218  NDDA: 0.9800  min_eigenvalue: -0.043182 max_grad_norm:2.88770e-02
# epoch:  9600  GD  loss/N: -0.477295  NDDA: 0.9770  min_eigenvalue: -0.002578 max_grad_norm:5.47370e-02
# epoch:  9700  GD  loss/N: -0.477328  NDDA: 0.9780  min_eigenvalue: -0.002618 max_grad_norm:1.75737e-02
# Switching to CPA at epoch 9721 due to small gradient norm: 1.49808e-02
# Switching back to GD at epoch 9724 due to large gradient norm: 1.88686e-02
# epoch:  9800  GD  loss/N: -0.477372  NDDA: 0.9800  min_eigenvalue: -0.038978 max_grad_norm:3.96024e-02
# epoch:  9900  GD  loss/N: -0.477430  NDDA: 0.9790  min_eigenvalue: -0.004389 max_grad_norm:3.33817e-02
# Switching to CPA at epoch 9991 due to small gradient norm: 1.49168e-02
# Switching back to GD at epoch 9996 due to large gradient norm: 1.98492e-02
# epoch: 10000  GD  loss/N: -0.477476  NDDA: 0.9810  min_eigenvalue: -0.022399 max_grad_norm:2.03668e-02
# epoch: 10100  GD  loss/N: -0.477501  NDDA: 0.9800  min_eigenvalue: -0.029455 max_grad_norm:2.94441e-02
# epoch: 10200  GD  loss/N: -0.477547  NDDA: 0.9850  min_eigenvalue: -0.074447 max_grad_norm:5.94955e-02
# epoch: 10300  GD  loss/N: -0.477697  NDDA: 0.9840  min_eigenvalue: -0.000075 max_grad_norm:3.44062e-02
# Switching to CPA at epoch 10382 due to small gradient norm: 1.49408e-02
# Switching back to GD at epoch 10393 due to large gradient norm: 1.54535e-02
# epoch: 10400  GD  loss/N: -0.477739  NDDA: 0.9810  min_eigenvalue: -0.031136 max_grad_norm:1.63327e-02
# epoch: 10500  GD  loss/N: -0.477769  NDDA: 0.9840  min_eigenvalue: -0.109213 max_grad_norm:7.00375e-02
# epoch: 10600  GD  loss/N: -0.478070  NDDA: 0.9790  min_eigenvalue: -0.001987 max_grad_norm:3.35422e-02
# Switching to CPA at epoch 10676 due to small gradient norm: 1.49679e-02
# Switching back to GD at epoch 10682 due to large gradient norm: 1.86255e-02
# epoch: 10700  GD  loss/N: -0.478099  NDDA: 0.9830  min_eigenvalue: -0.042777 max_grad_norm:2.23185e-02
# epoch: 10800  GD  loss/N: -0.478372  NDDA: 0.9820  min_eigenvalue: -0.004118 max_grad_norm:2.70342e-01
# epoch: 10900  GD  loss/N: -0.478624  NDDA: 0.9790  min_eigenvalue: -0.004561 max_grad_norm:2.11400e-02
# Switching to CPA at epoch 10940 due to small gradient norm: 1.49029e-02
# Switching back to GD at epoch 10945 due to large gradient norm: 2.38897e-02
# epoch: 11000  GD  loss/N: -0.478661  NDDA: 0.9830  min_eigenvalue: -0.035154 max_grad_norm:3.98924e-02
# epoch: 11100  GD  loss/N: -0.478711  NDDA: 0.9840  min_eigenvalue: -0.000126 max_grad_norm:3.34746e-02
# Switching to CPA at epoch 11199 due to small gradient norm: 1.49790e-02
# epoch: 11200  CPA  loss/N: -0.478725  NDDA: 0.9820  min_eigenvalue: -0.000115 max_grad_norm:1.47276e-02
# Switching back to GD at epoch 11212 due to large gradient norm: 2.57349e-02
# epoch: 11300  GD  loss/N: -0.478959  NDDA: 0.9870  min_eigenvalue: -0.053653 max_grad_norm:1.50128e-01
# epoch: 11400  GD  loss/N: -0.479329  NDDA: 0.9830  min_eigenvalue: -0.099037 max_grad_norm:8.77111e-02
# epoch: 11500  GD  loss/N: -0.479544  NDDA: 0.9870  min_eigenvalue: -0.001966 max_grad_norm:3.11387e-02
# Switching to CPA at epoch 11577 due to small gradient norm: 1.49487e-02
# Switching back to GD at epoch 11585 due to large gradient norm: 1.51286e-02
# epoch: 11600  GD  loss/N: -0.479593  NDDA: 0.9850  min_eigenvalue: -0.025617 max_grad_norm:1.65744e-02
# epoch: 11700  GD  loss/N: -0.479608  NDDA: 0.9850  min_eigenvalue: -0.028181 max_grad_norm:3.41355e-02
# epoch: 11800  GD  loss/N: -0.479644  NDDA: 0.9840  min_eigenvalue: -0.000014 max_grad_norm:3.25701e-02
# epoch: 11900  GD  loss/N: -0.479657  NDDA: 0.9850  min_eigenvalue: -0.000013 max_grad_norm:1.59457e-02
# Switching to CPA at epoch 11911 due to small gradient norm: 1.49415e-02
# Switching back to GD at epoch 11929 due to large gradient norm: 1.62134e-02
# epoch: 12000  GD  loss/N: -0.479685  NDDA: 0.9890  min_eigenvalue: -0.034064 max_grad_norm:2.70955e-02
# epoch: 12100  GD  loss/N: -0.479720  NDDA: 0.9830  min_eigenvalue: -0.000949 max_grad_norm:4.33054e-02
# epoch: 12200  GD  loss/N: -0.479746  NDDA: 0.9840  min_eigenvalue: -0.000976 max_grad_norm:2.08049e-02
# Switching to CPA at epoch 12251 due to small gradient norm: 1.49338e-02
# Switching back to GD at epoch 12259 due to large gradient norm: 1.99102e-02
# epoch: 12300  GD  loss/N: -0.479782  NDDA: 0.9870  min_eigenvalue: -0.055963 max_grad_norm:3.09343e-02
# epoch: 12400  GD  loss/N: -0.480040  NDDA: 0.9830  min_eigenvalue: -0.047330 max_grad_norm:1.14460e-01
# epoch: 12500  GD  loss/N: -0.480222  NDDA: 0.9840  min_eigenvalue: -0.018814 max_grad_norm:9.65172e-02
# epoch: 12600  GD  loss/N: -0.480300  NDDA: 0.9840  min_eigenvalue: -0.035674 max_grad_norm:2.27641e-02
# epoch: 12700  GD  loss/N: -0.480346  NDDA: 0.9870  min_eigenvalue: -0.111703 max_grad_norm:8.12443e-02
# epoch: 12800  GD  loss/N: -0.480592  NDDA: 0.9820  min_eigenvalue: -0.015534 max_grad_norm:3.69371e-02
# Switching to CPA at epoch 12894 due to small gradient norm: 1.49482e-02
# Switching back to GD at epoch 12895 due to large gradient norm: 2.19787e-02
# epoch: 12900  GD  loss/N: -0.480620  NDDA: 0.9860  min_eigenvalue: -0.019454 max_grad_norm:2.24751e-02
# epoch: 13000  GD  loss/N: -0.480638  NDDA: 0.9850  min_eigenvalue: -0.000461 max_grad_norm:2.71422e-02
# epoch: 13100  GD  loss/N: -0.480652  NDDA: 0.9840  min_eigenvalue: -0.000437 max_grad_norm:1.84610e-02
# Switching to CPA at epoch 13144 due to small gradient norm: 1.49950e-02
# Switching back to GD at epoch 13154 due to large gradient norm: 1.86523e-02
# epoch: 13200  GD  loss/N: -0.480687  NDDA: 0.9800  min_eigenvalue: -0.048660 max_grad_norm:2.83031e-02
# epoch: 13300  GD  loss/N: -0.480791  NDDA: 0.9850  min_eigenvalue: -0.006580 max_grad_norm:1.06936e-01
# epoch: 13400  GD  loss/N: -0.480876  NDDA: 0.9800  min_eigenvalue: -0.007392 max_grad_norm:2.53803e-02
# Switching to CPA at epoch 13468 due to small gradient norm: 1.49715e-02
# Switching back to GD at epoch 13473 due to large gradient norm: 1.86246e-02
# epoch: 13500  GD  loss/N: -0.480903  NDDA: 0.9810  min_eigenvalue: -0.039841 max_grad_norm:2.31057e-02
# epoch: 13600  GD  loss/N: -0.480950  NDDA: 0.9810  min_eigenvalue: -0.053631 max_grad_norm:7.98700e-02
# epoch: 13700  GD  loss/N: -0.481056  NDDA: 0.9830  min_eigenvalue: -0.026821 max_grad_norm:3.33734e-02
# epoch: 13800  GD  loss/N: -0.481078  NDDA: 0.9790  min_eigenvalue: -0.051958 max_grad_norm:3.30313e-02
# epoch: 13900  GD  loss/N: -0.481172  NDDA: 0.9830  min_eigenvalue: -0.000117 max_grad_norm:7.97406e-02
# epoch: 14000  GD  loss/N: -0.481224  NDDA: 0.9820  min_eigenvalue: -0.000181 max_grad_norm:2.39472e-02
# Switching to CPA at epoch 14066 due to small gradient norm: 1.49810e-02
# Switching back to GD at epoch 14077 due to large gradient norm: 3.01826e-02
# epoch: 14100  GD  loss/N: -0.481267  NDDA: 0.9820  min_eigenvalue: -0.063267 max_grad_norm:3.97941e-02
# epoch: 14200  GD  loss/N: -0.481409  NDDA: 0.9830  min_eigenvalue: -0.004929 max_grad_norm:7.79292e-02
# epoch: 14300  GD  loss/N: -0.481450  NDDA: 0.9810  min_eigenvalue: -0.003514 max_grad_norm:2.16826e-02
# Switching to CPA at epoch 14354 due to small gradient norm: 1.49543e-02
# Switching back to GD at epoch 14361 due to large gradient norm: 1.71799e-02
# epoch: 14400  GD  loss/N: -0.481481  NDDA: 0.9810  min_eigenvalue: -0.044037 max_grad_norm:2.34543e-02
# epoch: 14500  GD  loss/N: -0.481558  NDDA: 0.9810  min_eigenvalue: -0.152434 max_grad_norm:1.37098e-01
# epoch: 14600  GD  loss/N: -0.481884  NDDA: 0.9830  min_eigenvalue: -0.014267 max_grad_norm:3.81908e-02
# epoch: 14700  GD  loss/N: -0.481913  NDDA: 0.9800  min_eigenvalue: -0.020388 max_grad_norm:1.98204e-02
# Switching to CPA at epoch 14752 due to small gradient norm: 1.49268e-02
# Switching back to GD at epoch 14753 due to large gradient norm: 2.22678e-02
# epoch: 14800  GD  loss/N: -0.481937  NDDA: 0.9800  min_eigenvalue: -0.068993 max_grad_norm:3.71813e-02
# epoch: 14900  GD  loss/N: -0.482379  NDDA: 0.9800  min_eigenvalue: -0.000126 max_grad_norm:1.26669e-01
# epoch: 15000  GD  loss/N: -0.482446  NDDA: 0.9790  min_eigenvalue: -0.000127 max_grad_norm:2.24753e-02
# Switching to CPA at epoch 15058 due to small gradient norm: 1.49335e-02
# Switching back to GD at epoch 15074 due to large gradient norm: 1.88115e-02
# epoch: 15100  GD  loss/N: -0.482493  NDDA: 0.9830  min_eigenvalue: -0.039878 max_grad_norm:2.28244e-02
# epoch: 15200  GD  loss/N: -0.482565  NDDA: 0.9850  min_eigenvalue: -0.115870 max_grad_norm:7.68419e-02
# epoch: 15300  GD  loss/N: -0.483481  NDDA: 0.9810  min_eigenvalue: -0.000240 max_grad_norm:8.70480e-02
# epoch: 15400  GD  loss/N: -0.483562  NDDA: 0.9810  min_eigenvalue: -0.000236 max_grad_norm:2.18746e-02
# Switching to CPA at epoch 15457 due to small gradient norm: 1.49831e-02
# Switching back to GD at epoch 15469 due to large gradient norm: 1.75813e-02
# epoch: 15500  GD  loss/N: -0.483604  NDDA: 0.9820  min_eigenvalue: -0.028838 max_grad_norm:2.07492e-02
# epoch: 15600  GD  loss/N: -0.483619  NDDA: 0.9830  min_eigenvalue: -0.022295 max_grad_norm:3.63530e-02
# epoch: 15700  GD  loss/N: -0.483648  NDDA: 0.9850  min_eigenvalue: -0.001296 max_grad_norm:3.38754e-02
# epoch: 15800  GD  loss/N: -0.483661  NDDA: 0.9780  min_eigenvalue: -0.001351 max_grad_norm:1.92214e-02
# Switching to CPA at epoch 15851 due to small gradient norm: 1.49826e-02
# Switching back to GD at epoch 15862 due to large gradient norm: 1.97026e-02
# epoch: 15900  GD  loss/N: -0.483686  NDDA: 0.9890  min_eigenvalue: -0.051197 max_grad_norm:2.69673e-02
# epoch: 16000  GD  loss/N: -0.483797  NDDA: 0.9870  min_eigenvalue: -0.206533 max_grad_norm:1.99598e-01
# epoch: 16100  GD  loss/N: -0.484200  NDDA: 0.9850  min_eigenvalue: -0.002671 max_grad_norm:3.49098e-02
# epoch: 16200  GD  loss/N: -0.484210  NDDA: 0.9880  min_eigenvalue: -0.002819 max_grad_norm:1.55650e-02
# Switching to CPA at epoch 16207 due to small gradient norm: 1.49784e-02
# Switching back to GD at epoch 16218 due to large gradient norm: 1.53339e-02
# epoch: 16300  GD  loss/N: -0.484232  NDDA: 0.9900  min_eigenvalue: -0.047749 max_grad_norm:2.66615e-02
# epoch: 16400  GD  loss/N: -0.484288  NDDA: 0.9880  min_eigenvalue: -0.097860 max_grad_norm:1.05749e-01
# epoch: 16500  GD  loss/N: -0.484463  NDDA: 0.9870  min_eigenvalue: -0.000147 max_grad_norm:4.23719e-02
# epoch: 16600  GD  loss/N: -0.484477  NDDA: 0.9890  min_eigenvalue: -0.000126 max_grad_norm:1.78889e-02
# Switching to CPA at epoch 16632 due to small gradient norm: 1.49999e-02
# Switching back to GD at epoch 16650 due to large gradient norm: 1.72864e-02
# epoch: 16700  GD  loss/N: -0.484505  NDDA: 0.9900  min_eigenvalue: -0.044375 max_grad_norm:2.44053e-02
# epoch: 16800  GD  loss/N: -0.484544  NDDA: 0.9900  min_eigenvalue: -0.099045 max_grad_norm:8.32778e-02
# epoch: 16900  GD  loss/N: -0.484736  NDDA: 0.9920  min_eigenvalue: -0.007116 max_grad_norm:5.27391e-02
# epoch: 17000  GD  loss/N: -0.484767  NDDA: 0.9910  min_eigenvalue: -0.008152 max_grad_norm:2.06117e-02
# Switching to CPA at epoch 17058 due to small gradient norm: 1.49461e-02
# Switching back to GD at epoch 17065 due to large gradient norm: 1.69561e-02
# epoch: 17100  GD  loss/N: -0.484795  NDDA: 0.9910  min_eigenvalue: -0.036357 max_grad_norm:2.07277e-02
# epoch: 17200  GD  loss/N: -0.484812  NDDA: 0.9910  min_eigenvalue: -0.065710 max_grad_norm:4.83817e-02
# epoch: 17300  GD  loss/N: -0.484911  NDDA: 0.9910  min_eigenvalue: -0.000705 max_grad_norm:7.36627e-02
# epoch: 17400  GD  loss/N: -0.484949  NDDA: 0.9900  min_eigenvalue: -0.000815 max_grad_norm:2.67734e-02
# Switching to CPA at epoch 17499 due to small gradient norm: 1.49768e-02
# epoch: 17500  CPA  loss/N: -0.484956  NDDA: 0.9890  min_eigenvalue: -0.001881 max_grad_norm:1.27357e-02
# Switching back to GD at epoch 17509 due to large gradient norm: 1.63245e-02
# epoch: 17600  GD  loss/N: -0.484980  NDDA: 0.9900  min_eigenvalue: -0.034066 max_grad_norm:2.57627e-02
# epoch: 17700  GD  loss/N: -0.485000  NDDA: 0.9890  min_eigenvalue: -0.019372 max_grad_norm:4.35027e-02
# epoch: 17800  GD  loss/N: -0.485031  NDDA: 0.9880  min_eigenvalue: -0.000002 max_grad_norm:3.66065e-02
# epoch: 17900  GD  loss/N: -0.485044  NDDA: 0.9910  min_eigenvalue: -0.000002 max_grad_norm:2.10776e-02
# Switching to CPA at epoch 17976 due to small gradient norm: 1.49985e-02
# epoch: 18000  CPA  loss/N: -0.485058  NDDA: 0.9900  min_eigenvalue: -0.009592 max_grad_norm:4.85179e-03
# Switching back to GD at epoch 18005 due to large gradient norm: 1.85647e-02
# epoch: 18100  GD  loss/N: -0.485078  NDDA: 0.9930  min_eigenvalue: -0.070725 max_grad_norm:3.91426e-02
# epoch: 18200  GD  loss/N: -0.485294  NDDA: 0.9910  min_eigenvalue: -0.002770 max_grad_norm:2.08516e-01
# epoch: 18300  GD  loss/N: -0.485465  NDDA: 0.9920  min_eigenvalue: -0.003240 max_grad_norm:3.53374e-02
# epoch: 18400  GD  loss/N: -0.485474  NDDA: 0.9920  min_eigenvalue: -0.003432 max_grad_norm:1.73144e-02
# Switching to CPA at epoch 18430 due to small gradient norm: 1.49875e-02
# Switching back to GD at epoch 18434 due to large gradient norm: 1.57493e-02
# epoch: 18500  GD  loss/N: -0.485491  NDDA: 0.9920  min_eigenvalue: -0.036770 max_grad_norm:2.18206e-02
# epoch: 18600  GD  loss/N: -0.485507  NDDA: 0.9930  min_eigenvalue: -0.056893 max_grad_norm:4.45200e-02
# epoch: 18700  GD  loss/N: -0.485571  NDDA: 0.9930  min_eigenvalue: -0.000045 max_grad_norm:7.17569e-02
# epoch: 18800  GD  loss/N: -0.485612  NDDA: 0.9920  min_eigenvalue: -0.000042 max_grad_norm:3.25669e-02
# epoch: 18900  GD  loss/N: -0.485622  NDDA: 0.9910  min_eigenvalue: -0.000041 max_grad_norm:1.80578e-02
# Switching to CPA at epoch 18943 due to small gradient norm: 1.49976e-02
# Switching back to GD at epoch 18966 due to large gradient norm: 1.63602e-02
# epoch: 19000  GD  loss/N: -0.485645  NDDA: 0.9950  min_eigenvalue: -0.034600 max_grad_norm:1.92195e-02
# epoch: 19100  GD  loss/N: -0.485655  NDDA: 0.9910  min_eigenvalue: -0.059141 max_grad_norm:3.71637e-02
# epoch: 19200  GD  loss/N: -0.485719  NDDA: 0.9940  min_eigenvalue: -0.031625 max_grad_norm:9.87177e-02
# epoch: 19300  GD  loss/N: -0.485812  NDDA: 0.9910  min_eigenvalue: -0.010538 max_grad_norm:4.55935e-02
# epoch: 19400  GD  loss/N: -0.485827  NDDA: 0.9930  min_eigenvalue: -0.012560 max_grad_norm:2.18780e-02
# Switching to CPA at epoch 19482 due to small gradient norm: 1.49804e-02
# Switching back to GD at epoch 19486 due to large gradient norm: 1.50119e-02
# epoch: 19500  GD  loss/N: -0.485840  NDDA: 0.9910  min_eigenvalue: -0.029609 max_grad_norm:1.58892e-02
# epoch: 19600  GD  loss/N: -0.485847  NDDA: 0.9910  min_eigenvalue: -0.047106 max_grad_norm:2.66939e-02
# epoch: 19700  GD  loss/N: -0.485872  NDDA: 0.9930  min_eigenvalue: -0.088835 max_grad_norm:6.60613e-02
# epoch: 19800  GD  loss/N: -0.486015  NDDA: 0.9910  min_eigenvalue: -0.000002 max_grad_norm:8.88124e-02
# epoch: 19900  GD  loss/N: -0.486058  NDDA: 0.9910  min_eigenvalue: -0.000002 max_grad_norm:3.16533e-02
# epoch: 20000  GD  loss/N: -0.486066  NDDA: 0.9910  min_eigenvalue: -0.000002 max_grad_norm:1.79198e-02
# Switching to CPA at epoch 20044 due to small gradient norm: 1.49790e-02
# Switching back to GD at epoch 20088 due to large gradient norm: 2.08386e-02
# epoch: 20100  GD  loss/N: -0.486095  NDDA: 0.9900  min_eigenvalue: -0.028941 max_grad_norm:2.18137e-02
# epoch: 20200  GD  loss/N: -0.486106  NDDA: 0.9910  min_eigenvalue: -0.026979 max_grad_norm:3.21361e-02
# epoch: 20300  GD  loss/N: -0.486125  NDDA: 0.9930  min_eigenvalue: -0.026493 max_grad_norm:3.90327e-02
# epoch: 20400  GD  loss/N: -0.486146  NDDA: 0.9910  min_eigenvalue: -0.039469 max_grad_norm:3.09667e-02
# epoch: 20500  GD  loss/N: -0.486166  NDDA: 0.9890  min_eigenvalue: -0.070687 max_grad_norm:4.20775e-02
# epoch: 20600  GD  loss/N: -0.486256  NDDA: 0.9920  min_eigenvalue: -0.061520 max_grad_norm:1.35931e-01
# epoch: 20700  GD  loss/N: -0.486406  NDDA: 0.9910  min_eigenvalue: -0.005642 max_grad_norm:5.44285e-02
# epoch: 20800  GD  loss/N: -0.486426  NDDA: 0.9900  min_eigenvalue: -0.005899 max_grad_norm:2.50945e-02
# epoch: 20900  GD  loss/N: -0.486432  NDDA: 0.9900  min_eigenvalue: -0.006339 max_grad_norm:1.59595e-02
# Switching to CPA at epoch 20918 due to small gradient norm: 1.49680e-02
# Switching back to GD at epoch 20924 due to large gradient norm: 1.54312e-02
# epoch: 21000  GD  loss/N: -0.486453  NDDA: 0.9900  min_eigenvalue: -0.031848 max_grad_norm:2.01241e-02
# epoch: 21100  GD  loss/N: -0.486460  NDDA: 0.9900  min_eigenvalue: -0.040423 max_grad_norm:3.10919e-02
# epoch: 21200  GD  loss/N: -0.486479  NDDA: 0.9910  min_eigenvalue: -0.028969 max_grad_norm:4.92009e-02
# epoch: 21300  GD  loss/N: -0.486512  NDDA: 0.9900  min_eigenvalue: -0.002500 max_grad_norm:4.90356e-02
# epoch: 21400  GD  loss/N: -0.486531  NDDA: 0.9910  min_eigenvalue: -0.002928 max_grad_norm:3.12298e-02
# epoch: 21500  GD  loss/N: -0.486539  NDDA: 0.9920  min_eigenvalue: -0.003177 max_grad_norm:2.05258e-02
# Switching to CPA at epoch 21597 due to small gradient norm: 1.49718e-02
# epoch: 21600  CPA  loss/N: -0.486545  NDDA: 0.9900  min_eigenvalue: -0.005123 max_grad_norm:7.95032e-03
# Switching back to GD at epoch 21611 due to large gradient norm: 1.53946e-02
# epoch: 21700  GD  loss/N: -0.486569  NDDA: 0.9930  min_eigenvalue: -0.038189 max_grad_norm:2.13102e-02
# epoch: 21800  GD  loss/N: -0.486578  NDDA: 0.9930  min_eigenvalue: -0.058424 max_grad_norm:3.57436e-02
# epoch: 21900  GD  loss/N: -0.486611  NDDA: 0.9930  min_eigenvalue: -0.081046 max_grad_norm:7.87643e-02
# epoch: 22000  GD  loss/N: -0.486715  NDDA: 0.9940  min_eigenvalue: -0.021790 max_grad_norm:8.52157e-02
# epoch: 22100  GD  loss/N: -0.486755  NDDA: 0.9920  min_eigenvalue: -0.024593 max_grad_norm:3.82077e-02
# epoch: 22200  GD  loss/N: -0.486767  NDDA: 0.9910  min_eigenvalue: -0.031303 max_grad_norm:2.25266e-02
# epoch: 22300  GD  loss/N: -0.486775  NDDA: 0.9890  min_eigenvalue: -0.043542 max_grad_norm:2.44148e-02
# epoch: 22400  GD  loss/N: -0.486787  NDDA: 0.9920  min_eigenvalue: -0.067725 max_grad_norm:4.22532e-02
# epoch: 22500  GD  loss/N: -0.486832  NDDA: 0.9900  min_eigenvalue: -0.081447 max_grad_norm:9.66240e-02
# epoch: 22600  GD  loss/N: -0.486946  NDDA: 0.9870  min_eigenvalue: -0.002655 max_grad_norm:8.22947e-02
# epoch: 22700  GD  loss/N: -0.486979  NDDA: 0.9890  min_eigenvalue: -0.003452 max_grad_norm:3.78430e-02
# epoch: 22800  GD  loss/N: -0.486988  NDDA: 0.9900  min_eigenvalue: -0.003645 max_grad_norm:2.30795e-02
# epoch: 22900  GD  loss/N: -0.486992  NDDA: 0.9920  min_eigenvalue: -0.003695 max_grad_norm:1.64195e-02
# Switching to CPA at epoch 22933 due to small gradient norm: 1.49806e-02
# epoch: 23000  CPA  loss/N: -0.487011  NDDA: 0.9870  min_eigenvalue: -0.001940 max_grad_norm:9.80157e-04
# Switching back to GD at epoch 23020 due to large gradient norm: 1.53917e-02
# epoch: 23100  GD  loss/N: -0.487037  NDDA: 0.9890  min_eigenvalue: -0.031997 max_grad_norm:1.91478e-02
# epoch: 23200  GD  loss/N: -0.487043  NDDA: 0.9870  min_eigenvalue: -0.040638 max_grad_norm:2.67056e-02
# epoch: 23300  GD  loss/N: -0.487056  NDDA: 0.9890  min_eigenvalue: -0.048724 max_grad_norm:4.02508e-02
# epoch: 23400  GD  loss/N: -0.487083  NDDA: 0.9900  min_eigenvalue: -0.034661 max_grad_norm:5.96805e-02
# epoch: 23500  GD  loss/N: -0.487124  NDDA: 0.9880  min_eigenvalue: -0.039697 max_grad_norm:5.88990e-02
# epoch: 23600  GD  loss/N: -0.487158  NDDA: 0.9860  min_eigenvalue: -0.041764 max_grad_norm:4.17796e-02
# epoch: 23700  GD  loss/N: -0.487194  NDDA: 0.9880  min_eigenvalue: -0.056177 max_grad_norm:5.27771e-02
# epoch: 23800  GD  loss/N: -0.487240  NDDA: 0.9900  min_eigenvalue: -0.097844 max_grad_norm:6.53107e-02
# epoch: 23900  GD  loss/N: -0.487364  NDDA: 0.9880  min_eigenvalue: -0.025529 max_grad_norm:1.51738e-01
# epoch: 24000  GD  loss/N: -0.487505  NDDA: 0.9850  min_eigenvalue: -0.025007 max_grad_norm:7.53836e-02
# epoch: 24100  GD  loss/N: -0.487541  NDDA: 0.9860  min_eigenvalue: -0.031910 max_grad_norm:3.85215e-02
# epoch: 24200  GD  loss/N: -0.487557  NDDA: 0.9870  min_eigenvalue: -0.042135 max_grad_norm:2.52036e-02
# epoch: 24300  GD  loss/N: -0.487570  NDDA: 0.9890  min_eigenvalue: -0.060017 max_grad_norm:3.31806e-02
# epoch: 24400  GD  loss/N: -0.487590  NDDA: 0.9870  min_eigenvalue: -0.096826 max_grad_norm:5.89806e-02
# epoch: 24500  GD  loss/N: -0.487662  NDDA: 0.9870  min_eigenvalue: -0.125747 max_grad_norm:1.46546e-01
# epoch: 24600  GD  loss/N: -0.487851  NDDA: 0.9850  min_eigenvalue: -0.003305 max_grad_norm:1.13640e-01
# epoch: 24700  GD  loss/N: -0.487899  NDDA: 0.9870  min_eigenvalue: -0.003557 max_grad_norm:5.08045e-02
# epoch: 24800  GD  loss/N: -0.487914  NDDA: 0.9840  min_eigenvalue: -0.003744 max_grad_norm:3.11954e-02
# epoch: 24900  GD  loss/N: -0.487921  NDDA: 0.9870  min_eigenvalue: -0.003910 max_grad_norm:2.23608e-02
# epoch: 25000  GD  loss/N: -0.487926  NDDA: 0.9850  min_eigenvalue: -0.004068 max_grad_norm:1.74234e-02
# Switching to CPA at epoch 25074 due to small gradient norm: 1.49899e-02
# Switching back to GD at epoch 25084 due to large gradient norm: 1.74972e-02
# epoch: 25100  GD  loss/N: -0.487955  NDDA: 0.9840  min_eigenvalue: -0.030698 max_grad_norm:1.80691e-02
# epoch: 25200  GD  loss/N: -0.487958  NDDA: 0.9860  min_eigenvalue: -0.036366 max_grad_norm:2.24938e-02
# epoch: 25300  GD  loss/N: -0.487962  NDDA: 0.9850  min_eigenvalue: -0.043159 max_grad_norm:2.90185e-02
# epoch: 25400  GD  loss/N: -0.487969  NDDA: 0.9870  min_eigenvalue: -0.049247 max_grad_norm:3.88489e-02
# epoch: 25500  GD  loss/N: -0.487982  NDDA: 0.9850  min_eigenvalue: -0.045943 max_grad_norm:5.25342e-02
# epoch: 25600  GD  loss/N: -0.488003  NDDA: 0.9850  min_eigenvalue: -0.014585 max_grad_norm:6.41338e-02
# epoch: 25700  GD  loss/N: -0.488028  NDDA: 0.9840  min_eigenvalue: -0.000023 max_grad_norm:6.07111e-02
# epoch: 25800  GD  loss/N: -0.488045  NDDA: 0.9860  min_eigenvalue: -0.000050 max_grad_norm:4.74957e-02
# epoch: 25900  GD  loss/N: -0.488055  NDDA: 0.9860  min_eigenvalue: -0.000065 max_grad_norm:3.59647e-02
# epoch: 26000  GD  loss/N: -0.488061  NDDA: 0.9850  min_eigenvalue: -0.000074 max_grad_norm:2.80533e-02
# epoch: 26100  GD  loss/N: -0.488064  NDDA: 0.9850  min_eigenvalue: -0.000080 max_grad_norm:2.27190e-02
# epoch: 26200  GD  loss/N: -0.488067  NDDA: 0.9850  min_eigenvalue: -0.000083 max_grad_norm:1.90036e-02
# epoch: 26300  GD  loss/N: -0.488069  NDDA: 0.9840  min_eigenvalue: -0.000086 max_grad_norm:1.63130e-02
# Switching to CPA at epoch 26362 due to small gradient norm: 1.49982e-02
# epoch: 26400  CPA  loss/N: -0.488084  NDDA: 0.9850  min_eigenvalue: -0.003884 max_grad_norm:2.02349e-03
# Switching back to GD at epoch 26420 due to large gradient norm: 1.52434e-02
# epoch: 26500  GD  loss/N: -0.488094  NDDA: 0.9850  min_eigenvalue: -0.019738 max_grad_norm:1.64371e-02
# epoch: 26600  GD  loss/N: -0.488095  NDDA: 0.9870  min_eigenvalue: -0.019702 max_grad_norm:1.80319e-02
# epoch: 26700  GD  loss/N: -0.488097  NDDA: 0.9860  min_eigenvalue: -0.019041 max_grad_norm:1.97001e-02
# epoch: 26800  GD  loss/N: -0.488099  NDDA: 0.9860  min_eigenvalue: -0.017552 max_grad_norm:2.13671e-02
# epoch: 26900  GD  loss/N: -0.488101  NDDA: 0.9850  min_eigenvalue: -0.015075 max_grad_norm:2.29241e-02
# epoch: 27000  GD  loss/N: -0.488103  NDDA: 0.9880  min_eigenvalue: -0.011572 max_grad_norm:2.42381e-02
# epoch: 27100  GD  loss/N: -0.488105  NDDA: 0.9860  min_eigenvalue: -0.007197 max_grad_norm:2.51779e-02
# epoch: 27200  GD  loss/N: -0.488108  NDDA: 0.9850  min_eigenvalue: -0.002303 max_grad_norm:2.56512e-02
# epoch: 27300  GD  loss/N: -0.488110  NDDA: 0.9860  min_eigenvalue: -0.000011 max_grad_norm:2.56347e-02
# epoch: 27400  GD  loss/N: -0.488113  NDDA: 0.9870  min_eigenvalue: -0.000011 max_grad_norm:2.51788e-02
# epoch: 27500  GD  loss/N: -0.488115  NDDA: 0.9870  min_eigenvalue: -0.000011 max_grad_norm:2.43855e-02
# epoch: 27600  GD  loss/N: -0.488117  NDDA: 0.9870  min_eigenvalue: -0.000011 max_grad_norm:2.33738e-02
# epoch: 27700  GD  loss/N: -0.488118  NDDA: 0.9860  min_eigenvalue: -0.000011 max_grad_norm:2.22522e-02
# epoch: 27800  GD  loss/N: -0.488120  NDDA: 0.9850  min_eigenvalue: -0.000011 max_grad_norm:2.11043e-02
# epoch: 27900  GD  loss/N: -0.488121  NDDA: 0.9870  min_eigenvalue: -0.000011 max_grad_norm:1.99864e-02
# epoch: 28000  GD  loss/N: -0.488122  NDDA: 0.9860  min_eigenvalue: -0.000011 max_grad_norm:1.89323e-02
# epoch: 28100  GD  loss/N: -0.488123  NDDA: 0.9880  min_eigenvalue: -0.000011 max_grad_norm:1.79590e-02
# epoch: 28200  GD  loss/N: -0.488124  NDDA: 0.9850  min_eigenvalue: -0.000011 max_grad_norm:1.70728e-02
# epoch: 28300  GD  loss/N: -0.488125  NDDA: 0.9850  min_eigenvalue: -0.000012 max_grad_norm:1.62732e-02
# epoch: 28400  GD  loss/N: -0.488125  NDDA: 0.9870  min_eigenvalue: -0.000012 max_grad_norm:1.55563e-02
# Switching to CPA at epoch 28487 due to small gradient norm: 1.49953e-02
# epoch: 28500  CPA  loss/N: -0.488129  NDDA: 0.9860  min_eigenvalue: -0.000017 max_grad_norm:9.94708e-03
# epoch: 28600  CPA  loss/N: -0.488135  NDDA: 0.9860  min_eigenvalue: -0.000679 max_grad_norm:3.40029e-04
# epoch: 28700  CPA  loss/N: -0.488144  NDDA: 0.9920  min_eigenvalue: -0.017129 max_grad_norm:8.80535e-03
# Switching back to GD at epoch 28721 due to large gradient norm: 1.57668e-02
# epoch: 28800  GD  loss/N: -0.488152  NDDA: 0.9920  min_eigenvalue: -0.031283 max_grad_norm:1.64525e-02
# epoch: 28900  GD  loss/N: -0.488153  NDDA: 0.9930  min_eigenvalue: -0.032874 max_grad_norm:1.73397e-02
# epoch: 29000  GD  loss/N: -0.488154  NDDA: 0.9920  min_eigenvalue: -0.034478 max_grad_norm:1.82402e-02
# epoch: 29100  GD  loss/N: -0.488154  NDDA: 0.9900  min_eigenvalue: -0.036075 max_grad_norm:1.91432e-02
# epoch: 29200  GD  loss/N: -0.488155  NDDA: 0.9920  min_eigenvalue: -0.037643 max_grad_norm:2.00354e-02
# epoch: 29300  GD  loss/N: -0.488155  NDDA: 0.9950  min_eigenvalue: -0.039156 max_grad_norm:2.09017e-02
# epoch: 29400  GD  loss/N: -0.488156  NDDA: 0.9930  min_eigenvalue: -0.040584 max_grad_norm:2.17247e-02
# epoch: 29500  GD  loss/N: -0.488156  NDDA: 0.9920  min_eigenvalue: -0.041896 max_grad_norm:2.24858e-02
# epoch: 29600  GD  loss/N: -0.488157  NDDA: 0.9950  min_eigenvalue: -0.043062 max_grad_norm:2.31657e-02
# epoch: 29700  GD  loss/N: -0.488157  NDDA: 0.9910  min_eigenvalue: -0.044052 max_grad_norm:2.37456e-02
# epoch: 29800  GD  loss/N: -0.488158  NDDA: 0.9910  min_eigenvalue: -0.044838 max_grad_norm:2.42081e-02
# epoch: 29900  GD  loss/N: -0.488158  NDDA: 0.9920  min_eigenvalue: -0.045398 max_grad_norm:2.45383e-02
# epoch:     0  GD  loss/N: -0.000625  NDDA: 0.3100  min_eigenvalue: -1.130604 max_grad_norm:7.24616e-01
# epoch:   100  GD  loss/N: -0.433626  NDDA: 0.0190  min_eigenvalue: -0.265006 max_grad_norm:2.31984e-01
# epoch:   200  GD  loss/N: -0.445326  NDDA: 0.0110  min_eigenvalue: -0.217907 max_grad_norm:2.14515e-01
# epoch:   300  GD  loss/N: -0.450072  NDDA: 0.0080  min_eigenvalue: -0.111950 max_grad_norm:2.24749e-01
# epoch:   400  GD  loss/N: -0.452903  NDDA: 0.0050  min_eigenvalue: -0.178196 max_grad_norm:1.53341e-01
# epoch:   500  GD  loss/N: -0.457972  NDDA: 0.0020  min_eigenvalue: -0.040066 max_grad_norm:6.22369e-02
# epoch:   600  GD  loss/N: -0.458639  NDDA: 0.0070  min_eigenvalue: -0.068042 max_grad_norm:4.77419e-02
# epoch:   700  GD  loss/N: -0.459355  NDDA: 0.0010  min_eigenvalue: -0.053046 max_grad_norm:1.90422e-01
# epoch:   800  GD  loss/N: -0.460547  NDDA: 0.0010  min_eigenvalue: -0.096972 max_grad_norm:7.22347e-02
# epoch:   900  GD  loss/N: -0.461567  NDDA: 0.0030  min_eigenvalue: -0.041826 max_grad_norm:2.96189e-02
# epoch:  1000  GD  loss/N: -0.462578  NDDA: 0.0010  min_eigenvalue: -0.112592 max_grad_norm:1.31257e-01
# epoch:  1100  GD  loss/N: -0.462930  NDDA: 0.0020  min_eigenvalue: -0.092369 max_grad_norm:5.72902e-02
# epoch:  1200  GD  loss/N: -0.463328  NDDA: 0.0020  min_eigenvalue: -0.101629 max_grad_norm:8.17917e-02
# epoch:  1300  GD  loss/N: -0.463597  NDDA: 0.0000  min_eigenvalue: -0.004254 max_grad_norm:1.80062e-02
# Switching to PGD at epoch 1316 due to small gradient norm: 1.49181e-02
# Switching back to GD at epoch 1317 due to large gradient norm: 2.36990e-02
# Switching to PGD at epoch 1350 due to small gradient norm: 1.49172e-02
# Switching back to GD at epoch 1351 due to large gradient norm: 6.42421e-02
# epoch:  1400  GD  loss/N: -0.463395  NDDA: 0.0000  min_eigenvalue: -0.029042 max_grad_norm:1.88306e-02
# epoch:  1500  GD  loss/N: -0.463620  NDDA: 0.0010  min_eigenvalue: -0.009758 max_grad_norm:8.05596e-02
# epoch:  1600  GD  loss/N: -0.463776  NDDA: 0.0030  min_eigenvalue: -0.015499 max_grad_norm:1.50334e-02
# Switching to PGD at epoch 1601 due to small gradient norm: 1.48815e-02
# Switching back to GD at epoch 1602 due to large gradient norm: 3.12848e-02
# epoch:  1700  GD  loss/N: -0.463985  NDDA: 0.0030  min_eigenvalue: -0.015417 max_grad_norm:9.87668e-02
# epoch:  1800  GD  loss/N: -0.464140  NDDA: 0.0000  min_eigenvalue: -0.049301 max_grad_norm:3.18182e-02
# epoch:  1900  GD  loss/N: -0.464508  NDDA: 0.0020  min_eigenvalue: -0.032203 max_grad_norm:1.41713e-01
# epoch:  2000  GD  loss/N: -0.464846  NDDA: 0.0010  min_eigenvalue: -0.021909 max_grad_norm:9.74323e-02
# epoch:  2100  GD  loss/N: -0.464965  NDDA: 0.0000  min_eigenvalue: -0.040479 max_grad_norm:3.32277e-02
# epoch:  2200  GD  loss/N: -0.465069  NDDA: 0.0010  min_eigenvalue: -0.023163 max_grad_norm:2.66125e-02
# epoch:  2300  GD  loss/N: -0.465130  NDDA: 0.0060  min_eigenvalue: -0.082804 max_grad_norm:5.34463e-02
# epoch:  2400  GD  loss/N: -0.465380  NDDA: 0.0030  min_eigenvalue: -0.027364 max_grad_norm:2.26737e-02
# epoch:  2500  GD  loss/N: -0.465500  NDDA: 0.0050  min_eigenvalue: -0.106248 max_grad_norm:1.46088e-01
# epoch:  2600  GD  loss/N: -0.465768  NDDA: 0.0020  min_eigenvalue: -0.013477 max_grad_norm:3.09595e-02
# epoch:  2700  GD  loss/N: -0.465814  NDDA: 0.0010  min_eigenvalue: -0.023160 max_grad_norm:1.62734e-02
# Switching to PGD at epoch 2711 due to small gradient norm: 1.49095e-02
# Switching back to GD at epoch 2712 due to large gradient norm: 1.89058e-02
# Switching to PGD at epoch 2741 due to small gradient norm: 1.49505e-02
# Switching back to GD at epoch 2743 due to large gradient norm: 5.01521e-02
# epoch:  2800  GD  loss/N: -0.465660  NDDA: 0.0030  min_eigenvalue: -0.035825 max_grad_norm:2.36350e-02
# epoch:  2900  GD  loss/N: -0.465936  NDDA: 0.0030  min_eigenvalue: -0.063741 max_grad_norm:8.20017e-02
# epoch:  3000  GD  loss/N: -0.466532  NDDA: 0.0010  min_eigenvalue: -0.014177 max_grad_norm:2.98211e-02
# Switching to PGD at epoch 3049 due to small gradient norm: 1.48540e-02
# Switching back to GD at epoch 3050 due to large gradient norm: 3.49426e-02
# epoch:  3100  GD  loss/N: -0.466512  NDDA: 0.0040  min_eigenvalue: -0.016848 max_grad_norm:1.63062e-02
# Switching to PGD at epoch 3108 due to small gradient norm: 1.49694e-02
# Switching back to GD at epoch 3109 due to large gradient norm: 2.34609e-02
# Switching to PGD at epoch 3155 due to small gradient norm: 1.49194e-02
# Switching back to GD at epoch 3156 due to large gradient norm: 1.99148e-02
# Switching to PGD at epoch 3179 due to small gradient norm: 1.49672e-02
# Switching back to GD at epoch 3180 due to large gradient norm: 3.25470e-02
# epoch:  3200  GD  loss/N: -0.466387  NDDA: 0.0070  min_eigenvalue: -0.018268 max_grad_norm:2.42997e-02
# Switching to PGD at epoch 3245 due to small gradient norm: 1.49816e-02
# Switching back to GD at epoch 3246 due to large gradient norm: 2.75520e-02
# epoch:  3300  GD  loss/N: -0.466426  NDDA: 0.0050  min_eigenvalue: -0.022151 max_grad_norm:2.72448e-02
# epoch:  3400  GD  loss/N: -0.466558  NDDA: 0.0080  min_eigenvalue: -0.007443 max_grad_norm:1.91093e-02
# Switching to PGD at epoch 3437 due to small gradient norm: 1.49074e-02
# Switching back to GD at epoch 3438 due to large gradient norm: 2.93722e-02
# Switching to PGD at epoch 3484 due to small gradient norm: 1.49967e-02
# Switching back to GD at epoch 3485 due to large gradient norm: 4.26789e-02
# epoch:  3500  GD  loss/N: -0.466470  NDDA: 0.0050  min_eigenvalue: -0.012085 max_grad_norm:2.93536e-02
# Switching to PGD at epoch 3567 due to small gradient norm: 1.49367e-02
# Switching back to GD at epoch 3568 due to large gradient norm: 3.53066e-02
# epoch:  3600  GD  loss/N: -0.466532  NDDA: 0.0070  min_eigenvalue: -0.035120 max_grad_norm:1.97370e-02
# epoch:  3700  GD  loss/N: -0.466908  NDDA: 0.0120  min_eigenvalue: -0.026408 max_grad_norm:9.10898e-02
# epoch:  3800  GD  loss/N: -0.467177  NDDA: 0.0070  min_eigenvalue: -0.020838 max_grad_norm:1.07550e-01
# epoch:  3900  GD  loss/N: -0.467355  NDDA: 0.0090  min_eigenvalue: -0.082877 max_grad_norm:4.79267e-02
# epoch:  4000  GD  loss/N: -0.467738  NDDA: 0.0070  min_eigenvalue: -0.002456 max_grad_norm:2.58470e-02
# Switching to PGD at epoch 4043 due to small gradient norm: 1.49433e-02
# Switching back to GD at epoch 4045 due to large gradient norm: 3.46663e-02
# epoch:  4100  GD  loss/N: -0.467674  NDDA: 0.0100  min_eigenvalue: -0.013600 max_grad_norm:1.58147e-02
# Switching to PGD at epoch 4106 due to small gradient norm: 1.49153e-02
# Switching back to GD at epoch 4107 due to large gradient norm: 2.56212e-02
# epoch:  4200  GD  loss/N: -0.467709  NDDA: 0.0090  min_eigenvalue: -0.006439 max_grad_norm:1.78110e-02
# Switching to PGD at epoch 4262 due to small gradient norm: 1.49802e-02
# Switching back to GD at epoch 4263 due to large gradient norm: 1.67357e-02
# Switching to PGD at epoch 4300 due to small gradient norm: 1.49777e-02
# epoch:  4300  PGD  loss/N: -0.467691  NDDA: 0.0060  min_eigenvalue: -0.014410 max_grad_norm:1.49777e-02
# Switching back to GD at epoch 4301 due to large gradient norm: 2.38879e-02
# Switching to PGD at epoch 4348 due to small gradient norm: 1.49609e-02
# Switching back to GD at epoch 4349 due to large gradient norm: 3.72655e-02
# epoch:  4400  GD  loss/N: -0.467676  NDDA: 0.0210  min_eigenvalue: -0.013520 max_grad_norm:1.73205e-02
# Switching to PGD at epoch 4469 due to small gradient norm: 1.49690e-02
# Switching back to GD at epoch 4470 due to large gradient norm: 1.59748e-02
# Switching to PGD at epoch 4486 due to small gradient norm: 1.49393e-02
# Switching back to GD at epoch 4487 due to large gradient norm: 2.90734e-02
# epoch:  4500  GD  loss/N: -0.467613  NDDA: 0.0220  min_eigenvalue: -0.006976 max_grad_norm:2.33463e-02
# Switching to PGD at epoch 4537 due to small gradient norm: 1.49277e-02
# Switching back to GD at epoch 4538 due to large gradient norm: 3.35731e-02
# ...
# epoch: 25300  GD  loss/N: -0.470363  NDDA: 0.3230  min_eigenvalue: -0.000078 max_grad_norm:1.53363e-02
# Switching to PGD at epoch 25312 due to small gradient norm: 1.49885e-02
# Switching back to GD at epoch 25313 due to large gradient norm: 1.59378e-02
# Switching to PGD at epoch 25345 due to small gradient norm: 1.49793e-02
# Switching back to GD at epoch 25346 due to large gradient norm: 1.56800e-02
# Switching to PGD at epoch 25370 due to small gradient norm: 1.49772e-02
# Switching back to GD at epoch 25371 due to large gradient norm: 1.90781e-02
# epoch: 25400  GD  loss/N: -0.470370  NDDA: 0.3200  min_eigenvalue: -0.000073 max_grad_norm:1.78543e-02
# Switching to PGD at epoch 25488 due to small gradient norm: 1.49739e-02
# Switching back to GD at epoch 25489 due to large gradient norm: 1.72038e-02
# epoch: 25500  GD  loss/N: -0.470374  NDDA: 0.3170  min_eigenvalue: -0.000071 max_grad_norm:1.68185e-02
# Switching to PGD at epoch 25560 due to small gradient norm: 1.49996e-02
# Switching back to GD at epoch 25565 due to large gradient norm: 1.86482e-02
# epoch: 25600  GD  loss/N: -0.470371  NDDA: 0.3240  min_eigenvalue: -0.000079 max_grad_norm:1.73071e-02
# Switching to PGD at epoch 25676 due to small gradient norm: 1.49932e-02
# Switching back to GD at epoch 25678 due to large gradient norm: 1.89683e-02
# epoch: 25700  GD  loss/N: -0.470378  NDDA: 0.3190  min_eigenvalue: -0.000091 max_grad_norm:1.80935e-02
# Switching to PGD at epoch 25800 due to small gradient norm: 1.49919e-02
# epoch: 25800  PGD  loss/N: -0.470386  NDDA: 0.3220  min_eigenvalue: -0.000091 max_grad_norm:1.49919e-02
# Switching back to GD at epoch 25801 due to large gradient norm: 1.78906e-02
# Switching to PGD at epoch 25898 due to small gradient norm: 1.49852e-02
# Switching back to GD at epoch 25899 due to large gradient norm: 1.64870e-02
# epoch: 25900  GD  loss/N: -0.470390  NDDA: 0.3220  min_eigenvalue: -0.000084 max_grad_norm:1.64570e-02
# Switching to PGD at epoch 25954 due to small gradient norm: 1.49952e-02
# Switching back to GD at epoch 25955 due to large gradient norm: 1.64479e-02
# epoch: 26000  GD  loss/N: -0.470395  NDDA: 0.3290  min_eigenvalue: -0.000088 max_grad_norm:1.52266e-02
# Switching to PGD at epoch 26010 due to small gradient norm: 1.49809e-02
# Switching back to GD at epoch 26011 due to large gradient norm: 1.56109e-02
# Switching to PGD at epoch 26036 due to small gradient norm: 1.49842e-02
# Switching back to GD at epoch 26038 due to large gradient norm: 1.64104e-02
# Switching to PGD at epoch 26093 due to small gradient norm: 1.49769e-02
# Switching back to GD at epoch 26094 due to large gradient norm: 1.51134e-02
# Switching to PGD at epoch 26099 due to small gradient norm: 1.49941e-02
# epoch: 26100  PGD  loss/N: -0.470394  NDDA: 0.3350  min_eigenvalue: -0.000108 max_grad_norm:1.39235e-02
# Switching back to GD at epoch 26107 due to large gradient norm: 1.57010e-02
# Switching to PGD at epoch 26136 due to small gradient norm: 1.49968e-02
# Switching back to GD at epoch 26137 due to large gradient norm: 1.50156e-02
# Switching to PGD at epoch 26138 due to small gradient norm: 1.49925e-02
# Switching back to GD at epoch 26139 due to large gradient norm: 1.55225e-02
# Switching to PGD at epoch 26161 due to small gradient norm: 1.49980e-02
# Switching back to GD at epoch 26162 due to large gradient norm: 1.73641e-02
# epoch: 26200  GD  loss/N: -0.470380  NDDA: 0.3230  min_eigenvalue: -0.000118 max_grad_norm:1.62752e-02
# Switching to PGD at epoch 26253 due to small gradient norm: 1.49784e-02
# Switching back to GD at epoch 26262 due to large gradient norm: 1.73533e-02
# epoch: 26300  GD  loss/N: -0.470377  NDDA: 0.3300  min_eigenvalue: -0.000105 max_grad_norm:1.62916e-02
# Switching to PGD at epoch 26355 due to small gradient norm: 1.49794e-02
# Switching back to GD at epoch 26359 due to large gradient norm: 1.53293e-02
# Switching to PGD at epoch 26374 due to small gradient norm: 1.49957e-02
# Switching back to GD at epoch 26375 due to large gradient norm: 1.68406e-02
# epoch: 26400  GD  loss/N: -0.470371  NDDA: 0.3200  min_eigenvalue: -0.000087 max_grad_norm:1.61863e-02
# Switching to PGD at epoch 26452 due to small gradient norm: 1.49865e-02
# Switching back to GD at epoch 26453 due to large gradient norm: 1.59856e-02
# Switching to PGD at epoch 26497 due to small gradient norm: 1.49958e-02
# epoch: 26500  PGD  loss/N: -0.470374  NDDA: 0.3320  min_eigenvalue: -0.000093 max_grad_norm:1.25402e-02
# Switching back to GD at epoch 26519 due to large gradient norm: 1.53126e-02
# Switching to PGD at epoch 26534 due to small gradient norm: 1.49962e-02
# Switching back to GD at epoch 26536 due to large gradient norm: 1.52190e-02
# Switching to PGD at epoch 26547 due to small gradient norm: 1.49872e-02
# Switching back to GD at epoch 26549 due to large gradient norm: 1.53142e-02
# Switching to PGD at epoch 26565 due to small gradient norm: 1.49799e-02
# Switching back to GD at epoch 26566 due to large gradient norm: 1.56410e-02
# Switching to PGD at epoch 26597 due to small gradient norm: 1.49841e-02
# epoch: 26600  PGD  loss/N: -0.470351  NDDA: 0.3350  min_eigenvalue: -0.000065 max_grad_norm:1.23856e-02
# Switching back to GD at epoch 26607 due to large gradient norm: 1.51105e-02
# Switching to PGD at epoch 26613 due to small gradient norm: 1.49861e-02
# Switching back to GD at epoch 26614 due to large gradient norm: 1.86124e-02
# epoch: 26700  GD  loss/N: -0.470358  NDDA: 0.3360  min_eigenvalue: -0.000103 max_grad_norm:1.62607e-02
# Switching to PGD at epoch 26759 due to small gradient norm: 1.49883e-02
# Switching back to GD at epoch 26762 due to large gradient norm: 1.60692e-02
# epoch: 26800  GD  loss/N: -0.470358  NDDA: 0.3430  min_eigenvalue: -0.000090 max_grad_norm:1.52574e-02
# Switching to PGD at epoch 26814 due to small gradient norm: 1.49808e-02
# Switching back to GD at epoch 26820 due to large gradient norm: 1.60836e-02
# Switching to PGD at epoch 26873 due to small gradient norm: 1.49923e-02
# Switching back to GD at epoch 26886 due to large gradient norm: 1.50522e-02
# Switching to PGD at epoch 26889 due to small gradient norm: 1.49952e-02
# Switching back to GD at epoch 26891 due to large gradient norm: 1.54994e-02
# epoch: 26900  GD  loss/N: -0.470350  NDDA: 0.3380  min_eigenvalue: -0.000141 max_grad_norm:1.53193e-02
# Switching to PGD at epoch 26917 due to small gradient norm: 1.49915e-02
# Switching back to GD at epoch 26920 due to large gradient norm: 1.54809e-02
# Switching to PGD at epoch 26945 due to small gradient norm: 1.49984e-02
# Switching back to GD at epoch 26953 due to large gradient norm: 1.51179e-02
# Switching to PGD at epoch 26960 due to small gradient norm: 1.49875e-02
# Switching back to GD at epoch 26961 due to large gradient norm: 1.55201e-02
# Switching to PGD at epoch 26989 due to small gradient norm: 1.49882e-02
# Switching back to GD at epoch 26990 due to large gradient norm: 1.56763e-02
# epoch: 27000  GD  loss/N: -0.470348  NDDA: 0.3380  min_eigenvalue: -0.000190 max_grad_norm:1.54794e-02
# Switching to PGD at epoch 27026 due to small gradient norm: 1.49927e-02
# Switching back to GD at epoch 27027 due to large gradient norm: 1.50847e-02
# Switching to PGD at epoch 27032 due to small gradient norm: 1.49941e-02
# Switching back to GD at epoch 27033 due to large gradient norm: 1.52213e-02
# Switching to PGD at epoch 27046 due to small gradient norm: 1.49832e-02
# Switching back to GD at epoch 27047 due to large gradient norm: 1.66828e-02
# epoch: 27100  GD  loss/N: -0.470349  NDDA: 0.3340  min_eigenvalue: -0.000164 max_grad_norm:1.55891e-02
# Switching to PGD at epoch 27133 due to small gradient norm: 1.49860e-02
# Switching back to GD at epoch 27134 due to large gradient norm: 1.59298e-02
# Switching to PGD at epoch 27185 due to small gradient norm: 1.49908e-02
# Switching back to GD at epoch 27186 due to large gradient norm: 1.73572e-02
# epoch: 27200  GD  loss/N: -0.470354  NDDA: 0.3250  min_eigenvalue: -0.000174 max_grad_norm:1.70419e-02
# epoch: 27300  GD  loss/N: -0.470361  NDDA: 0.3380  min_eigenvalue: -0.000173 max_grad_norm:1.51174e-02
# Switching to PGD at epoch 27308 due to small gradient norm: 1.49846e-02
# Switching back to GD at epoch 27309 due to large gradient norm: 1.53493e-02
# Switching to PGD at epoch 27330 due to small gradient norm: 1.49969e-02
# Switching back to GD at epoch 27356 due to large gradient norm: 1.55944e-02
# Switching to PGD at epoch 27392 due to small gradient norm: 1.49930e-02
# Switching back to GD at epoch 27393 due to large gradient norm: 1.71935e-02
# epoch: 27400  GD  loss/N: -0.470365  NDDA: 0.3330  min_eigenvalue: -0.000163 max_grad_norm:1.70483e-02
# epoch: 27500  GD  loss/N: -0.470370  NDDA: 0.3310  min_eigenvalue: -0.000164 max_grad_norm:1.52443e-02
# Switching to PGD at epoch 27516 due to small gradient norm: 1.49961e-02
# Switching back to GD at epoch 27517 due to large gradient norm: 1.57851e-02
# Switching to PGD at epoch 27567 due to small gradient norm: 1.49925e-02
# Switching back to GD at epoch 27568 due to large gradient norm: 1.62257e-02
# epoch: 27600  GD  loss/N: -0.470370  NDDA: 0.3360  min_eigenvalue: -0.000155 max_grad_norm:1.56893e-02
# Switching to PGD at epoch 27646 due to small gradient norm: 1.49878e-02
# Switching back to GD at epoch 27648 due to large gradient norm: 1.57067e-02
# Switching to PGD at epoch 27696 due to small gradient norm: 1.49885e-02
# epoch: 27700  PGD  loss/N: -0.470373  NDDA: 0.3330  min_eigenvalue: -0.000142 max_grad_norm:1.16327e-02
# Switching back to GD at epoch 27736 due to large gradient norm: 1.54534e-02
# Switching to PGD at epoch 27768 due to small gradient norm: 1.49981e-02
# Switching back to GD at epoch 27769 due to large gradient norm: 1.62827e-02
# epoch: 27800  GD  loss/N: -0.470364  NDDA: 0.3290  min_eigenvalue: -0.000162 max_grad_norm:1.58001e-02
# Switching to PGD at epoch 27857 due to small gradient norm: 1.49984e-02
# Switching back to GD at epoch 27864 due to large gradient norm: 1.72997e-02
# epoch: 27900  GD  loss/N: -0.470365  NDDA: 0.3500  min_eigenvalue: -0.000163 max_grad_norm:1.66977e-02
# epoch: 28000  GD  loss/N: -0.470369  NDDA: 0.3310  min_eigenvalue: -0.000164 max_grad_norm:1.52667e-02
# Switching to PGD at epoch 28022 due to small gradient norm: 1.49921e-02
# epoch: 28100  PGD  loss/N: -0.470364  NDDA: 0.3340  min_eigenvalue: -0.000144 max_grad_norm:1.27003e-02
# Switching back to GD at epoch 28116 due to large gradient norm: 1.52366e-02
# Switching to PGD at epoch 28137 due to small gradient norm: 1.49938e-02
# Switching back to GD at epoch 28141 due to large gradient norm: 1.52882e-02
# Switching to PGD at epoch 28167 due to small gradient norm: 1.49909e-02
# Switching back to GD at epoch 28169 due to large gradient norm: 1.56759e-02
# epoch: 28200  GD  loss/N: -0.470361  NDDA: 0.3300  min_eigenvalue: -0.000104 max_grad_norm:1.53109e-02
# Switching to PGD at epoch 28229 due to small gradient norm: 1.49893e-02
# Switching back to GD at epoch 28239 due to large gradient norm: 1.50968e-02
# Switching to PGD at epoch 28248 due to small gradient norm: 1.49998e-02
# Switching back to GD at epoch 28249 due to large gradient norm: 1.52546e-02
# Switching to PGD at epoch 28273 due to small gradient norm: 1.49958e-02
# Switching back to GD at epoch 28274 due to large gradient norm: 1.51464e-02
# Switching to PGD at epoch 28288 due to small gradient norm: 1.49981e-02
# Switching back to GD at epoch 28290 due to large gradient norm: 1.50129e-02
# Switching to PGD at epoch 28292 due to small gradient norm: 1.49921e-02
# Switching back to GD at epoch 28297 due to large gradient norm: 1.50280e-02
# Switching to PGD at epoch 28300 due to small gradient norm: 1.49963e-02
# epoch: 28300  PGD  loss/N: -0.470358  NDDA: 0.3520  min_eigenvalue: -0.000135 max_grad_norm:1.49963e-02
# Switching back to GD at epoch 28314 due to large gradient norm: 1.55379e-02
# Switching to PGD at epoch 28365 due to small gradient norm: 1.49928e-02
# Switching back to GD at epoch 28366 due to large gradient norm: 1.61288e-02
# epoch: 28400  GD  loss/N: -0.470357  NDDA: 0.3400  min_eigenvalue: -0.000181 max_grad_norm:1.57427e-02
# Switching to PGD at epoch 28473 due to small gradient norm: 1.49962e-02
# Switching back to GD at epoch 28474 due to large gradient norm: 1.50814e-02
# Switching to PGD at epoch 28483 due to small gradient norm: 1.49955e-02
# Switching back to GD at epoch 28484 due to large gradient norm: 1.58809e-02
# epoch: 28500  GD  loss/N: -0.470359  NDDA: 0.3310  min_eigenvalue: -0.000185 max_grad_norm:1.57139e-02
# Switching to PGD at epoch 28575 due to small gradient norm: 1.49956e-02
# Switching back to GD at epoch 28576 due to large gradient norm: 1.53005e-02
# epoch: 28600  GD  loss/N: -0.470361  NDDA: 0.3430  min_eigenvalue: -0.000199 max_grad_norm:1.50827e-02
# Switching to PGD at epoch 28610 due to small gradient norm: 1.49948e-02
# Switching back to GD at epoch 28677 due to large gradient norm: 1.52793e-02
# epoch: 28700  GD  loss/N: -0.470363  NDDA: 0.3550  min_eigenvalue: -0.000257 max_grad_norm:1.50845e-02
# Switching to PGD at epoch 28711 due to small gradient norm: 1.49943e-02
# Switching back to GD at epoch 28712 due to large gradient norm: 1.52022e-02
# Switching to PGD at epoch 28737 due to small gradient norm: 1.49981e-02
# Switching back to GD at epoch 28746 due to large gradient norm: 1.54646e-02
# epoch: 28800  GD  loss/N: -0.470363  NDDA: 0.3430  min_eigenvalue: -0.000317 max_grad_norm:1.50313e-02
# Switching to PGD at epoch 28805 due to small gradient norm: 1.49936e-02
# Switching back to GD at epoch 28809 due to large gradient norm: 1.53279e-02
# Switching to PGD at epoch 28853 due to small gradient norm: 1.49946e-02
# Switching back to GD at epoch 28854 due to large gradient norm: 1.50139e-02
# Switching to PGD at epoch 28856 due to small gradient norm: 1.49992e-02
# Switching back to GD at epoch 28868 due to large gradient norm: 1.50704e-02
# Switching to PGD at epoch 28878 due to small gradient norm: 1.49986e-02
# Switching back to GD at epoch 28881 due to large gradient norm: 1.61867e-02
# epoch: 28900  GD  loss/N: -0.470358  NDDA: 0.3610  min_eigenvalue: -0.000342 max_grad_norm:1.60318e-02
# epoch: 29000  GD  loss/N: -0.470360  NDDA: 0.3440  min_eigenvalue: -0.000343 max_grad_norm:1.53005e-02
# Switching to PGD at epoch 29048 due to small gradient norm: 1.49938e-02
# Switching back to GD at epoch 29049 due to large gradient norm: 1.51872e-02
# Switching to PGD at epoch 29080 due to small gradient norm: 1.49982e-02
# Switching back to GD at epoch 29081 due to large gradient norm: 1.51410e-02
# epoch: 29100  GD  loss/N: -0.470362  NDDA: 0.3490  min_eigenvalue: -0.000354 max_grad_norm:1.50283e-02
# Switching to PGD at epoch 29105 due to small gradient norm: 1.49992e-02
# epoch: 29200  PGD  loss/N: -0.470358  NDDA: 0.3400  min_eigenvalue: -0.000615 max_grad_norm:1.44137e-02
# epoch: 29300  PGD  loss/N: -0.470363  NDDA: 0.3430  min_eigenvalue: -0.000897 max_grad_norm:1.05622e-02
# Switching back to GD at epoch 29357 due to large gradient norm: 1.50188e-02
# Switching to PGD at epoch 29362 due to small gradient norm: 1.49976e-02
# Switching back to GD at epoch 29363 due to large gradient norm: 1.53844e-02
# epoch: 29400  GD  loss/N: -0.470359  NDDA: 0.3480  min_eigenvalue: -0.000888 max_grad_norm:1.52258e-02
# Switching to PGD at epoch 29458 due to small gradient norm: 1.49997e-02
# Switching back to GD at epoch 29460 due to large gradient norm: 1.51020e-02
# Switching to PGD at epoch 29489 due to small gradient norm: 1.49979e-02
# epoch: 29500  PGD  loss/N: -0.470357  NDDA: 0.3430  min_eigenvalue: -0.000897 max_grad_norm:1.47848e-02
# Switching back to GD at epoch 29503 due to large gradient norm: 1.50047e-02
# Switching to PGD at epoch 29505 due to small gradient norm: 1.49979e-02
# epoch: 29600  PGD  loss/N: -0.470358  NDDA: 0.3440  min_eigenvalue: -0.000994 max_grad_norm:1.29371e-02
# epoch: 29700  PGD  loss/N: -0.470359  NDDA: 0.3420  min_eigenvalue: -0.000890 max_grad_norm:1.26537e-02
# epoch: 29800  PGD  loss/N: -0.470359  NDDA: 0.3430  min_eigenvalue: -0.000850 max_grad_norm:1.34690e-02
# epoch: 29900  PGD  loss/N: -0.470358  NDDA: 0.3430  min_eigenvalue: -0.000921 max_grad_norm:1.46665e-02
# GD + CPA final loss: -0.48815802001953124
# GD + PGD final loss: -0.47035906982421877
